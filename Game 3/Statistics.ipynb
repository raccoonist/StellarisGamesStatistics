# %% [markdown]
# # Stellaris Game 3 Statistics

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# file paths
populationPath = "data/population.csv"
techScorePath = "data/techScore.csv"
economyScorePath = "data/economyScore.csv"

# %%
# read in all csvs
population = pd.read_csv(populationPath)
techScore = pd.read_csv(techScorePath)
economyScore = pd.read_csv(economyScorePath)

# %%
population
# Out:
#     Year  Patrick  Boxes  Noodles  Andrew  Godspeace Darren   Kage  Usagi  \
# 0   2219       43     42      NaN     NaN        NaN           NaN    NaN
# 1   2220       44     43      NaN     NaN        NaN    NaN    NaN    NaN
# 2   2221       45     43      NaN     NaN        NaN    NaN    NaN    NaN
# 3   2222       49     44      NaN     NaN        NaN    NaN    NaN    NaN
# 4   2223       50     45      NaN     NaN        NaN    NaN    NaN    NaN
# 5   2224       50     45     52.0    43.0       57.0     66   54.0    NaN
# 6   2225       54     44     55.0    43.0       59.0     69   54.0    NaN
# 7   2231       63     49     67.0    47.0       67.0     80   64.0   69.0
# 8   2236       83     56     81.0    52.0       81.0    108   75.0   87.0
# 9   2241      100     59     92.0    57.0       95.0    130   86.0   95.0
# 10  2262      210     80    149.0    87.0       43.0    257  155.0  152.0
# 11  2273      294     99    187.0   108.0       58.0    326  183.0  190.0
# ...

# %%
techScore
# Out:
#     Year  Patrick  Boxes  Noodles  Andrew  Godspeace  Darren  Kage  Usagi  \
# 0   2225      286    198      228     262        309     205   302    372
# 1   2233      404    264      329     405        440     315   439    505
# 2   2237      461    311      365     465        480     361   505    575
# 3   2241      541    355      428     516        541     440   561    654
# 4   2273     1130    625      994    1014        956    1454  1275   1520
# 5   2275     1226    625     1052    1078       1068    1586  1340   1592
# 6   2277     1271    661     1128    1116       1148    1711  1356   1649
# 7   2281     1401    712     1188    1152       1318    1930  1499   1761
# 8   2284     1662    756     1266    1218       1488    2130  1615   1916
# 9   2287     1934    821     1492    1311       1488    2379  1740   2078
# 10  2288     2096    862     1526    1336       1529    2479  1740   2208
# 11  2289     2166    882     1562    1356       1529    2559  1740   2258
# ...

# %%
economyScore
# Out:
#     Year   Patrick   Boxes   Noodles   Andrew   Godspeace   Darren   Kage  \
# 0   2225       584     511       620      958         549      759    531
# 1   2233       552     562       763     1061         726      967    660
# 2   2237       671     621       810      800         759     1174    767
# 3   2241       793     649       914      868         753     1260    837
# 4   2273      2236    1109      1907     1309         493     3003   1762
# 5   2275      2417    1194      2031     1336         481     3228   1845
# 6   2277      2564    1334      2227     1373         532     3456   1987
# 7   2281      2771    1521      2405     1420         572     3866   2306
# 8   2284      2998    1515      2253     1464         614     4006   2566
# 9   2287      3437    1497      2402     1572         680     4411   2627
# 10  2288      3488    1515      2365     1600         713     4514   2809
# 11  2289      3492    1513      2429     1623         712     4569   2771
# ...

# %%
population = population.dropna(axis=0, how='any').reset_index(drop=True)
population
# Out:
#     Year  Patrick  Boxes  Noodles  Andrew  Godspeace Darren   Kage  Usagi  \
# 0   2231       63     49     67.0    47.0       67.0     80   64.0   69.0
# 1   2236       83     56     81.0    52.0       81.0    108   75.0   87.0
# 2   2241      100     59     92.0    57.0       95.0    130   86.0   95.0
# 3   2262      210     80    149.0    87.0       43.0    257  155.0  152.0
# 4   2273      294     99    187.0   108.0       58.0    326  183.0  190.0
# 5   2275      322    103    196.0   114.0       62.0    348  192.0  192.0
# 6   2278      342    120    204.0   119.0       66.0    369  199.0  199.0
# 7   2281      376    129    216.0   130.0       70.0    394  216.0  210.0
# 8   2284      421    136    199.0   139.0       78.0    434  236.0  224.0
# 9   2287      446    143    191.0   149.0       82.0    466  253.0  233.0
# 10  2288      469    146    193.0   152.0       84.0    474  259.0  237.0
# 11  2289      473    146    195.0   153.0       84.0    482  265.0  239.0
# ...

# %%
merged = population.merge(techScore, how='right')
